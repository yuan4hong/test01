# %%
spark.sql("DROP TABLE IF EXISTS OCI_HSG_maestro_slurm_nodes")
spark.sql("""
    CREATE TABLE OCI_HSG_maestro_slurm_nodes
    USING parquet
    LOCATION 's3://edsp-dcartm-landing/hongy/upload//export_OCI_HSG_20260206_015013/slurm_nodes.parquet'
""")
spark.sql("DESCRIBE OCI_HSG_maestro_slurm_nodes").show(50, truncate=False)
spark.sql("SELECT * FROM OCI_HSG_maestro_slurm_nodes LIMIT 10").show(truncate=False)
